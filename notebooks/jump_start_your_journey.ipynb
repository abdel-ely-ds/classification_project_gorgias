# %%
import pandas as pd
from src.ticket_messages import TicketMessage
import ast
import swifter
import re

# %%
df = pd.read_parquet("data/classification_dataset")

# %%
df.tail()
# Out:
#       account_id ticket_id             raw_body channel  unix_timestamp  \
# 56167      47355  97704266 -7329393197999221857   email    1.683747e+09
# 56168      47355  97104492  -712526401448959206   email    1.683821e+09
# 56169      47355  98114244 -6396575246795551664   email    1.683823e+09
# 56170      47355  98375668  8956876459394868202   email    1.684164e+09
# 56171      47355  98834917  3230166170796936168   email    1.684271e+09
#
#                    contact_reason       processed_body  \
# 56167  "Pre-sale::Place an order"  7769862566240229096
# 56168     "No Action Req::Others"  8225526187121867386
# 56169     "No Action Req::Others"                    0
# 56170     "Tech Supp::Tech_Query"  4884952985295307657
# 56171        "Shipping::Tracking"  1023372247625818182
#
#                                email_sentence_embeddings
# 56167  {"7076610397638084948": [0.04829759523272514, ...
# 56168  {"-4707052099692602634": [0.04418250918388367,...
# 56169                                               None
# 56170  {"-6790423425691970518": [-0.10473562777042389...
# 56171  {"1824102601729972162": [-0.02185063622891903,...

# %%
df.shape
# Out:
# (56172, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56172 entries, 0 to 56171
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   account_id                 56172 non-null  object
#  1   ticket_id                  56172 non-null  object
#  2   raw_body                   56172 non-null  int64
#  3   channel                    56172 non-null  object
#  4   unix_timestamp             56172 non-null  float64
#  5   contact_reason             56172 non-null  object
#  6   processed_body             56172 non-null  int64
#  7   email_sentence_embeddings  50719 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.4+ MB

# %%
df.contact_reason.nunique()
# Out:
# 1776

# %%
df.ticket_id.nunique()
# Out:
# 56172

# %%
df.account_id.nunique()
# Out:
# 67

# %%
df[df["email_sentence_embeddings"] == ""]
# Out:
# Empty DataFrame
# Columns: [account_id, ticket_id, raw_body, channel, unix_timestamp, contact_reason, processed_body, email_sentence_embeddings]
# Index: []

# %%
df[df["email_sentence_embeddings"].isna()].shape
# Out:
# (5453, 8)

# %%
df[df["email_sentence_embeddings"].isna()].processed_body.nunique()
# Out:
# 713

# %%
df[df["email_sentence_embeddings"].isna()].groupby("processed_body").contact_reason.nunique().sort_values()
# Out:
# processed_body
# -9211444432197865303      1
#  2506378290563214752      1
#  2513959075871035925      1
#  2542718104208950957      1
#  2571804879116554174      1
#                        ...
#  121320659668196706       9
# -5442437062721334598     10
#  8659924373827760716     33
#  9200394132716385379    146
#  0                      467
# Name: contact_reason, Length: 713, dtype: int64

# %%
df = df[~df.email_sentence_embeddings.isna()]

# %%
df["email_sentence_embeddings"] = df["email_sentence_embeddings"].swifter.apply(lambda x: ast.literal_eval(x) if x is not None else x)
# Out:
# Pandas Apply: 100%|█████████████████████████████████████████████████████████████| 50719/50719 [06:25<00:00, 131.49it/s]

# %%
df["nb_sentences"] = df.email_sentence_embeddings.swifter.apply(len)
# Out:
# Pandas Apply: 100%|██████████████████████████████████████████████████████████| 50719/50719 [00:00<00:00, 539568.72it/s]

# %%
df.nb_sentences.describe(percentiles=[0.99])
# Out:
# count    50719.000000
# mean         2.306000
# std          4.758009
# min          1.000000
# 50%          1.000000
# 99%         16.000000
# max        225.000000
# Name: nb_sentences, dtype: float64

# %%
df.groupby("contact_reason").ticket_id.nunique().describe(percentiles=[0.99])
# Out:
# count    1707.000000
# mean       29.712361
# std       105.859004
# min         1.000000
# 50%         5.000000
# 99%       352.920000
# max      1829.000000
# Name: ticket_id, dtype: float64

# %%
text = "Subscription:: Cancel"

cleaned_text = re.sub(r'\s*::\s*', '::', text)

# %%
print(cleaned_text)
# Out:
# Subscription::Cancel

# %%
clean_classes = []
for c in df.contact_reason:
    clean_classes.append(re.sub(r'\s*::\s*', '::', c).replace('"', '').strip().lower())

# %%
len(set(clean_classes)), len(clean_classes)
# Out:
# (1681, 50719)

# %%
for c in set(clean_classes):
    print(c)
# Out:
# affiliate::wholesale::fit body boot camp
# system::discount code issue
# refunds & returns
# order::i need to change my order
# purchasing::international order::international quote request
# rwp::disp
# cancel request::too much
# order arrived late
# shipping::policy::international
# store message::order question
# received wrong product
# damaged::defective
# ambassador request
# order confirmation/vat receipt
# discount::newsletter
# product information::product repair
# wholesale::website/online account issue
# post-purchase
# amazon::bubbling mats
# production::delayed order
# sales support::product info::stk result query
# site tech::complaints::other site/tech issues
# other::thank you
# hotjar::exit::price
# sales support::social comment info only::social comment info only
# problem::address change
# place order::purchase order
# order support::order status::query on product application after order
# clean nutrition
# fulfillment::wismo
# wholesale::cancellation::full order
# shipping - change my order (edit,sizes)
# pre-sales::quote request
# product::complaint
# subscription::change frequency
# general issue: other
# returns- spanish delays
# received dated product
# pre-sale::discount::other
# production::bag issue
# return::refund
# return::how-to
# refund::courtesy
# shipping issue::address change
# subscription::amend
# damage/defect::damaged after wear/wash
# gift card::inquiry
# orders::shipping::shipping issue
# sales support::miscellaneous::logging in issue
# product feedback/request::feedback >> negative
# fulfilment::missing item::no damage to parcel
# shipping issue::stuck in transit
# delivery/shipping::package missing/lost
# customer::incorrectly ordered
# pre-sale::product::ingredients
# change/cancel order::change >> color
# order issue::missing order
# order issue::coupon code
# return::return to menē credit::return damage/defect
# order::edit/add to
# change/cancel order::change >> style
# place order::how do i
# qa::expired
# order inquiry::general
# billing & payment::payment issue::rebate / discount not applied
# international shipping
# account::unsubscribe::email
# external channel::amazon::order issue::other
# customer::purchase query
# pr::tara requests
# mobile app support::mode control::heat
# shipping issue::dhl
# order change::address change
# social media
# return/exchange::outside regular window
# shopping- sizing queries
# qa::dental
# exchange/return::initiate return
# order related::order cancellation::other
# retail::return::refund
# physical product::hardware::functionality
# refunds- refund not received
# order::wrong item
# feedback/request::request >> color request
# subscription::can't login
# cancel order
# biz::gorgias
# shopping- product availability
# general::international - don't ship
# mobile app support::temperature control
# product::sizing inquiry
# product::issue::sizing
# advertising
# other::paypal cancel
# order related::order return::fit issue::mens
# order issue::return::reaction
# domestic returns/refunds/exchanges::how do i make a return? 5b.
# sales support::product tech info::ingredients used
# returns-price complaint
# existing order::shipping/tracking::order status inquiry
# estore::freight enquiry
# order::change::cancel-request
# return::replace
# distribution::picking error
# wismo::post-shipped::delayed shipping - order in transit
# order support::issues with items::sprayer doesn't fit
# not-support-related::social media
# support::account
# product information::metal purity
# change to order::address
# product inquiry::customer product feedback
# product::tea school
# paypal
# demand response::other
# cancel request::purchase at cvs
# product information::product identification
# product inquiry::requests for product recommendation::modibodi
# return/exchange::return request::inside window
# brink's
# product information::pre-sales
# return::return to original payment method::return dislike
# marketing::promotions::other
# mobile app support::app crash::android
# order::change address
# pre-sale::account
# retail::where can i buy rem beauty in stores? (retailers). 16a.
# physical product::hardware::damaged
# shipping::shipment status::canada post
# subscriptions::general
# forwarding::blogger
# cancel & refund::not fulfilled::tax exemption
# other::new / unknown issue
# order related::order return::damaged product::womens
# returns::i need to return/exchange my order
# order status::order processing update
# order support::delivery status::awaiting test kit results
# return::return process
# digital product::content::curriculum
# stock adjustment::plap
# fulfillment::cancel order
# shipping::damaged in transit::ups
# shipping::misdelivered::fedex
# hardware issues::not powering on
# problem::forgot to apply my discount
# feedback::positive
# account access
# sfn return notification
# digital product::classroom management::clever integration
# shipping::lost in transit::ups::no vcare coverage
# quality issue::wipes
# product::product comparison
# shipping::shipment status::international
# subscription::update personal information
# post-purchase::shipping::lost/damaged::usps
# question::product information
# post-purchase::return::narvar issue
# place order::take payment
# wholesale::order issue::coupon code
# affiliate::wholesale::affiliate
# physical product::known issue-closed::bolt erratic driving
# order::missing items::unclear/tbd
# amscan::order cancellation request from customer
# exchange/return::defective
# order::return request
# reviews::courier complaint (delivered)
# post-purchase::shipping::other
# sf pro account - discount not showing
# misc::other
# cx initiated
# cx initiated::judge.me
# pre-sales question
# received::missing item
# wholesale::wrong item::packing error
# existing order::rma::buyer's remorse
# digital product::website::general
# non service email::amazon notification
# shipping issue::address issue
# adjust watch
# return/exchange::general questions
# external channel::amazon::return request
# order::not shipped
# spam/non-support-related
# unknown issue
# estore::general
# marketing::how do i become an affiliate? 2b.
# damaged
# positive feedback
# full refund
# mobile app support::energy saving and reporting::mysa whole home energy
# refund::no longer using/general
# tracking::shipping status
# marketing::promotions::youth competition queries/feedback
# biz::paypal
# sales support::product tech info::product application
# order::request cancel
# shipping::delivered not received::refunded
# question::pre-sales
# return::return policy / request
# system::recharge issue
# misc::invoice request
# order issue::reship order
# problem::exchange
# shopping support::website support
# pre-sale::can't find needed item
# shipping::damaged in transit::ups::vcare coverage
# shipping - no order confirmation
# enquiry::product enquiry
# international ordering::do i have to pay duties and taxes? 7c.
# product query::other::authentication
# order related::order exchange::damaged product::womens
# spam/non-support-related::support logs (other platforms)
# change/cancel order::cancel request
# order issue::placing an order
# pre-purchase::sizing::womens
# cancel request::i didn't mean to subscribe
# wholesale::pdf::damaged::yodel
# post-purchase::shipping::late delivery::dhl
# amscan
# tracking::complaint
# order issue::edit order
# novelty/internal::product/policy
# order::other
# feedback and complaints::complaint / negative experience
# stock adjustment::disp
# resolved by phone/whatsapp
# digital product::account management::login/account help
# returns::not the right size
# procurement query
# order issue::return::other
# core issue: incorrect item sent
# b2b::check in
# shipping::delayed
# faulty::faulty garment::stain upon delivery
# buy::accessories
# we sell mats ads
# order support::delivery issue::shipment missing an item
# customer::delay order
# returns and exchanges::refund delay / issue
# shipping::tracking request
# order::exchange
# return&exchange::not eligible::final sale
# availability
# review::google::positive
# wholesale::outgoing messages::new order welcome
# shopping support::account support
# questions::antibiotics
# returns::returns policy provided::incorrect size too big::adult swimwear sports bikini bottom
# forwarding::hr
# post-purchase::feedback::cs/policy
# exchange request
# questions::other
# presale::issue::cart/checkout
# feedback/request::feedback >> general negative
# questions::shipping times
# website / digital product
# refund::no longer using
# post-purchase::transaction inquiry::pending charges
# estore::address error
# presale::product inquiry::material
# subscription adjustment
# corporate
# unsubscribe from spam
# ebay
# shipping issue: incorrect quantity
# biz dev::careers
# return&exchange::how to return/exchange?
# rewards::points expiration
# shopping support::pick-up request
# shipping::damaged in transit::capost:no vcare coverage
# pre-sale::place an order
# product related::recommendation
# product arrived damaged
# customer::new wholesale
# influencer::hlf
# bought-in::damaged
# pre-sale::price and lead time
# google::positive
# review::feefo::update
# wholesale query
# questions::product::other
# order issue::wismo
# order issue::return::non-issue
# billing & payment::refund inquiry
# technical support
# technical issue: cannot process payment
# cancel request::not working
# product query::sizing
# billing & payment::purchasing::mysa::rebate issue
# order support::cancel::no longer needed
# donations
# postscript/text
# order inquiry::address change request
# rewards::stacking with other discounts
# customer::cancellation request
# digital product::content::finding content
# damage / defect
# hotjar::exit::other
# other::donation
# other::discount request
# order support::issues with items::sprayer doesn't work
# order status::shipped::delivered
# order inquiry::bulk order
# spam/non-support-related::invoices/confirmations/support logs
# pre-sale::notify when in stock
# order issue::replacement
# order support::return/replacement::how to return an item
# purchasing::availability/stock
# collaboration::advertising/marketing
# presale::product inquiry::sizing
# feedback - constructive
# warrenty::cleaning mats
# questions::order
# shipping::fedex/usps::wismo
# purchasing::po submission
# presale::product inquiry::other
# auto reply
# problem::cancel order
# catch
# order::order status
# discount inquiry::code not entered at checkout
# presale::policy inquiry::return/exchange policy
# post-purchase::change order::address
# digital product::general
# shipping issue::wrong shipping address
# adverse reaction
# shipping - ndd delay
# sales support::price/discount::do you offer any discount?
# return&exchange::return policy
# did not receive samples
# received someone else's order
# return::update on return
# sale::coupon/discount
# promotional code
# distribution::stock issue
# unsubscribe
# domestic ordering::how can i find the status of my order? 3b.
# customer::invoice request
# change shipping option
# website issues and feedback::other feedback
# order change::add or remove product
# web assistance::referral code error
# subscription cancelation
# sale::notify when in stock
# wholesale::wismo::returned by courier
# pricing inquiry
# exchange/return::wrong size
# post-purchase::shipping::lost/damaged::dhl
# gift card::resend
# order inquiry::line item change request
# store message::routing
# rewards::other
# order inquiry::request to add gift message
# delivery/shipping::returned to sender (customer initiated)
# presale::issue::out of stock
# subscription::questions
# product::inquiry::samples
# sales support::product info::product safety
# external channel::target::other
# general::question
# shipping::where is my order?
# rewards/referral/account::rewards >> group chat/inner circle rewards
# faulty::faulty garment::incorrect label
# faulty::diffuser::power cuts after period
# return::refund::upset about fee
# tech supp::broken
# verification::bank deposit request
# delivery::rts
# shipping information::shipping general
# website::other
# refund::discount
# return/exchange::cancel/modify
# order issue::say delivered
# presale::issue::other
# shipping::delayed shipment::international
# order::cancel::already shipped
# other::other
# wismo::in pick
# shipping issue::lost in transit
# question::wholesale
# amazon::i would like to return or cancel my order
# pdf::damaged::bedding
# product::concern
# shipping::fedex/usps/canada post::damaged in transit
# order related::order return::other
# other::email spam
# other::email empty
# orders & deliveries::lost in transit
# return::other
# return::return to menē credit::return dislike
# wismo::pre-shipped::oversold
# order issue: quantity error re: customer error
# general::lingeriecycle
# product question
# payment terms::do we have account::no
# faulty product/ product complaint
# pre-sale::question::product
# order::change::uporder
# menē account::account creation
# product information::product customization
# customer::sample request
# styling
# product use::adverse reaction
# wholesale::faire::new order
# salesman - trying to sell us product
# order support::delivery issue::delivery delayed
# pdf::plant & advise
# faulty::diffuser::no mist
# place order
# shipping::costs
# cancel request::doc orders
# order::change::address change
# after-sales::warranty
# 60 day risk free trial::general policy inquiries
# sales support::product info::product effectivity
# retail::order issue::damage::repair
# fulfillment::wrong item
# mobile app support::smart alerts::filter cleaning
# after-sales::product operation
# wanting supplement advice
# hardware issues::heater not turning on
# shopping support::product request
# shipping::not received::ups
# general /admin::unsubscribe request
# update customer information
# returns::return label
# spam/non-suppport
# subscription save
# device setup::installation::issue
# purchasing::reseller inquiry
# shipping request::combine shipping
# damage
# rewards::void voucher
# refund::mbg::side effects/doc orders
# pro active::follow up::call back
# other::job request
# menē account::unsubscribe
# shipping - i want to cancel
# bulk::inquiry/request
# placing an order::payment
# fulfillment::edit order
# shipping::policy::us
# shipping::i did not receive my order
# pre-purchase::coupons
# pre-sales::ordering
# verification::cc and id request
# edit order
# pre-sale
# shipping::misdelivered::usps
# shipping::international
# order::feedback::positive
# returns::cust following up returned items
# cold call business service::ingredients
# damaged::third-party
# marketing
# pre-sale::coupon/discount
# receipt or invoice request
# returns & exchanges::return
# order::add promo
# wholesale
# order inquiry::discount did not apply
# shipping delay
# non service email::non service email
# pre-sale::product::other
# discounts and credits::compensation request
# physical product::legacy discontinued complaint
# tech supp::repeat issue
# refund::didn't mean to subscribe
# pre-purchase::discount request
# order::return/refund
# digital product::software::functionality
# post-purchase::shipping::xb::missing item
# recycling::non-customer
# account- unsubscribe
# general::wholesale
# stamped io
# hotjar::exit::newbrand
# damaged in shipping 100%
# other::other (not listed)
# general inquiry::store availability
# wrong item::packing error
# troubleshooting::error code::i3
# gifting
# pre-sale::product::bbd check
# pre-sale::product::query
# mobile app support::mode control::hold
# estore::oos/unfulfilled
# product request
# wanting us to delete their account
# startrack
# pr::other
# order related::order return::wrong item::home items
# flow message
# order::wrong items
# connectivity::wifi issue
# existing order::wismo
# sweet note
# order::lost
# order::missing item
# size/fit help::need help for items they received
# shipping questions
# orders::order timing
# shipping issue::return to sender
# order support::cancel::order placed by mistake
# verification::cancellation
# product special request::cord
# button / hardware replacement
# shipping - delays
# marketing::promotions::discount coupons::forgot to apply
# general question / return policy
# delivery/shipping
# shipping - delivery times info
# missing items
# pre-sale::drawing or photo
# order::edit::item
# points inquiry
# faulty- faulty
# inluencer query
# order::cancel/change
# social media::other
# questions::ingredients
# domestic ordering::when will my order ship? 3a.
# mobile app support::scheduling::early-on
# inappropriate email complaints
# return&exchange::exchange policy
# delivery - tracking says item delivered, but not received
# quality issue::wash
# general /admin::product suggestion
# shipping::tracking::out for delivery
# product::inquiry::presale
# orders::payment::discounts
# return::exchange
# shipping::canada shipping::delay/lost::canada post
# exchange
# external channel::amazon::a to z guarantee
# returns- i want to exchange
# post-purchase::return::defect
# order::wismo/tracking link/rts
# troubleshooting::error code::h3
# after-sales::returns & exchanges
# pre-sale::question
# return::gift return::no pop
# pre-sale::coupon / discount
# website::assistance
# cancel & refund::fulfilled::changed mind
# order::refund::partial
# faulty::faulty garment::hole/ripped fabric
# shipping::status inquiry
# site technical issue
# order::cancellation
# wholesale::wismo::not despatched
# billing & payment::fraud notification::high
# returns::returns policy provided::incorrect size too small::seamfree full brief
# order::charge
# sizing::complaint::too small
# spam/blank/auto replies
# cancel subscription
# pro active::follow up::return to sender
# social media::general question
# received::box was open
# sizing::complaint::too large
# existing order::change/cancel
# wholesaler
# website issue
# order::request change
# job enquiry::influencer
# cancel & refund::fulfilled::wrong item ordered
# wismo::post-shipped::i did not receive my tracking info
# wholesale::product information::pre-sales
# other::messagesentbymistake
# product feedback/quality::faulty/damaged::repair request
# order issue::cancel order
# product questions::other
# missing/mix-up
# rewards/referral/account::rewards >> how to redeem
# digital product::compatibility
# no action req::others
# damaged/faulty
# pre-purchase::restock
# support::donation/education/tax exempt
# mobile app support::smart alerts::home environment alerts
# sales support::product info::payment modes
# presale::policy inquiry::shipping policy
# cold call business service::other
# tracking::investigation
# others::nr
# sf pro account - subscription not linked to their account
# purchasing::payment issue
# question::other
# wrong item::flowered incorrectly
# shipping::general enquiry
# domestic ordering::what currency are the prices displayed on rembeauty.com? 3e.
# wholesale enquiry
# product missed from order
# wismo::missing (packing error)
# mobile app support::home environment notifications::multiple notifications / many notifications
# damaged device
# delivery/shipping::damaged package
# shipping status::shipping fulfillment update
# order support::order status::general inquiry on order status
# pro inquiry
# retail::general question
# education::documentation request
# shipping::arrived late
# rewards::reviews::points status
# account management::request to change email
# question::shipping information
# marketing::unsubscribe to newsletter/edm/surveys
# product overview::how can i find out more information about a product? 6e.
# product problem::product damage or defect
# restock
# b2b::order
# pre-sale::policy question
# account inquiry::unsubscribe me from email alerts
# usage updates::bad
# product information::engraving
# subscription::change subscription
# post-sales
# shipping - tracking not working
# order issue::missing package
# general social media
# product inquiry::bundle packs
# general sales::website/ tech issue
# other::ln test
# wismo::pre-shipped::i did not receive my tracking info
# product::issue::inconsistent fit
# marketing::promotions::discount coupons::general information
# physical product::manuals + documentation
# payment method::goldmoney
# non-support related
# qa::standard
# distribution::qc issue
# delivery/shipping::expedite request
# support::defective/warranty
# retail::order issue::missing item
# order issue::return::manufacturing issue
# order support::discount::discount not applied
# non service email::payment notification
# shipping request::expedite shipping
# product::inquiry
# pre sale question::product inquiry
# melted
# returns::returns complaint::cannot return due to new policy
# wismo::post-shipped::did not receive gift card
# shipping::not received::return to sender
# place an order
# order::shipping::inquiries
# wholesale::wismo::missing (packing error)
# other::admin
# pre-sale::discount::rewards points::points expired
# buy::parts
# order update
# mobile app support::energy saving and reporting::mysa whole home energy::new issue
# order::missing items::3rd party seller
# review::feefo::negative review
# product questions
# order management::order not shipped
# web issues
# production::quality issue
# existing order::order error::user error
# ask location
# invoice::invoice request
# product query
# wismo::post-shipped::order returned - failed delivery attempt
# order::quality issue
# pre-sale::wholesale
# others::spam
# general /admin::general inquiry
# order::cancel
# shopping- payment methods
# amazon::channel key info
# site tech::payment gateway
# pre-sales::products
# discount inquiry::other
# product::presale::freesamples
# social media question
# quality issue::defend
# payment terms::do we have account::yes
# shipping issue::lost package
# customer feedback
# order::order details / status
# order::order-issue::wrong item
# sales support::product info::general product info/inquiry
# post-purchase::discount::retroactively apply::same day
# shipping::delayed in transit
# faulty::faulty garment::hole in the gusset - manufacturing issue
# damage/defect
# return::status inquiry::in-transit
# account management::password::unable to reset password
# product::discount
# account::update details
# order::refund
# orders & deliveries::shipping delays eu::tracking number provided
# in transit
# hardware issues::touch / sensitivity issue
# problem::where's my refund
# demand response::bc hydro - peak rewards
# cold call business service::overseas
# general sales::out of stock
# product::feedback
# rewards::referral
# non service email
# problem::price adjustment
# wholesale::wismo::lost in transit
# spam/non-support-related::spam
# shipping::lost in transit::capost::vcare coverage
# order::status inquiry
# product::presale::productinquiry
# other::miscellaneous
# promotion
# order::order-issue::missing item
# product inquiry: ingredients, use
# feedback::subscription
# order::shipping/delivery issue
# bought-in::quality
# usage updates::good
# general question
# order related::order return::damaged product::home items
# novelty/internal::regulatory
# amazon::order issue::shipping
# product complaint / return
# order related::order exchange::damaged product::home items
# hardware issues::sensor issue (humidity / temperature reading)
# mobile app support::energy saving and reporting::mysa energy usage::incorrect
# forwarding::pr
# return/exchange::change of mind
# other::okendo reviews
# estore::genral
# subscription::change
# shipping issue::evri
# post sale product question
# order issue::re-route order
# spam/non-support-related::invoices/receipts/confirmations
# payment notification
# amazon::a to z guarantee
# other::ln notes
# order::discount code
# pre-sale::stock request
# item inquiry
# order::change address / shipping
# order incorrect::no issue, was correct
# wismo::pre-shipped::i did not receive my confirmation email
# return::status inquiry::return amount question
# website::app issues
# discount inquiry::code not entered at checkout (non-welcome)
# edit address
# digital product::software::download/installation
# spam::supplier
# non service email::junk mail
# product related::charger request
# international ordering
# payment issues
# contacting rem beauty::pr team. 17c.
# post-purchase::discount::retroactively apply::within month
# order::order-issue::quality/supplier-concern
# shopping support::product information
# retail::order issue::incorrect item
# general /admin::employment inquiry
# digital product::content::coding help
# pre-sale::quote::pricing and lead time
# mobile app support::energy saving and reporting::mysa monthly energy report::new issue
# retail::order issue::wrong address
# lost package
# return/exchange::wrong size
# product information::product care
# store message::customer question
# connectivity::disconnect(s)
# delivery/shipping::returned to sender (customer initiated ticket)
# shipping issue - bottle leak
# review::feefo::positive review
# order::damage
# pre-sale::corporate::bulk order enquiry
# digital product::content::finding app content
# order status::shipped::delays::dpd
# product query::stock
# apply promo
# order support::delivery status::where is my order?
# item out of stock
# pdf::poor on arrival
# shipping::passport
# returns::query
# digital product::software::bluetooth
# digital product::website::sphero.com account
# product::product recommendation
# discount code issue
# product feedback/request::request >> color request
# review::trust pilot::negative review
# order issue::return::damaged packaging
# post-purchase::feedback::other
# general sales::product application
# no action req::csat resp
# refund::mbg::not working
# external channel::amazon::other
# non service email::auto response
# order::issue::missing item(s)
# pre-sale::product questions
# order status::on-time
# account management::unsubscribe
# mobile app support::app crash::ios
# product::quality concern
# order support::refunds::refund request
# wholesale::pdf::poor on arrival
# feedback/request::feedback >> general positive
# socials
# subscription::swap product
# influencer- collaboration request
# no-reply
# questions::for men
# order::wismo::on time
# size help
# novelty/internal::chargebacks/fraud
# product special request::earring backing
# product::product question
# mobile app support::scheduling::schedule not followed / triggered
# refund::shipping issues
# wanting the nutritional information of a product
# shipping::where is my order
# international returns/refunds/exchanges
# back in stock / waiting list
# wismo::not despatched
# return::policy questions
# oos- out of stock
# order::change::cancelorder
# post-purchase::change order::cancel order
# discount inquiry::welcome discount code (all)
# feedback::product
# sale::question
# shopping- product info
# usage updates::haven't started
# return::return received?
# production::extraction issue
# birthday code not received/doesn't work
# return/exchange::military address
# product information::product idea
# other::social media spam
# sales support::price/discount::discount not working
# express order not delivered the same day
# trademe
# core issue: stock
# delivered with issues - damaged parcel/items
# masterclass
# bought-in::faulty
# return&exchange::return status
# pre-purchase::product question
# change to order::sizing
# order::after sales
# website
# shipping::damaged in transit
# order::rush request
# tracking::delivered not received
# spam
# general
# shopping support::inventory inquiry
# shopping - wholesale
# feedback and complaints::marketing / sales request
# subscription::unsubscribe email & text
# subscription
# order support::edit order::change address
# discount or sample
# rewards/referral/account::rewards >> points (expired/missing/etc)
# pre-sale::spare parts list
# orders & deliveries::general shipping info (rates/country/time etc)
# shipping::rts
# shipping - tracking info request
# wholesale::faire message
# test
# customer::complaint
# pdf::damaged::evri
# refunds- refund not processed
# shipping::policy::canada
# digital product::sunsetting app complaint
# general /admin::calendly meeting invite
# pre-purchase
# walmart
# no question asked
# order amend
# cold call business service::3pl
# system::account access
# customer::data erasure request
# product questions::features
# post-purchase::feedback::product
# order status::delay::vendor delay
# damaged::within warranty
# subscription::reactivate subscription
# general sales::feedback
# return/exchange::outside 90day window
# cancel request::i want to purchase as needed
# order status::shipped::in-transit
# mobile app support::shared access::other issue
# pricing problem::menē fee discrepancy
# place order issue
# payment::paypal
# order::change::details
# product inquiry: other
# pre-sale::discount::rewards points::how to redeem
# returns & exchanges::store credit
# website/online account issue
# product::fit
# product::presale::samples
# marketing::promotions::refer a friend
# battery change
# fedex
# payment
# order::new::buyer
# no response
# product problem::weight variance
# shipping issue - lost / missing package
# change subscription
# delivered with issues - wrong item(s) / whole parcel
# purchasing::vendor paperwork
# question::order status
# shipping issue::delivery failure
# social
# customer::changed mind
# estore::returns
# digital product::classroom management::google classroom integration
# order::amend::amend address
# firmware and software updates::firmware out of date / not updating
# wismo::delivered
# enquiry::shipping enquiry
# subscription::cancel
# gift order::missing gift note
# order issue::return::compatibility
# no action req::survey
# other::unsubscribe
# discounts and credits::code not working
# web assistance::promo codes/discounts
# return::return to menē credit::return sizing
# shipping::fedex/usps::delivered not received
# quality control
# unsubscribe/mailing list
# returns and exchanges::return request
# product questions::restock
# wholesale::quote
# discounts
# troubleshooting::error code::other error code
# questions::other health related
# order issue::missing item
# quality issue::flush
# return::how to?
# general /admin::guest post
# retail::order issue::item out of stock
# return::mto
# order::i need to cancel my order
# site tech::complaints::promotions not working on site
# forwarding::ecom
# integration and automations::apple homekit::question / compatibility
# pdf::failed after planting
# customer::wholesale enquiry
# order::change
# shipping::where is my tracking information?
# post-purchase::change order::shipping method
# questions::product
# cancel request::no reason
# other::vendor invoice
# shipping issues::fedex
# order::invoice needed/sent
# order management::order not delivered
# cancel request::other
# brand/company::social stance/politics
# post-purchase::shipping::lost/damaged::fedex
# review::google::negative
# order::edit::address::in-state
# auto response
# orders::payment::others
# shipping issue::not received
# missed call
# retail
# website ux/technical issue::recycling
# physical product::hardware::battery
# sell::place an order
# technical::fraudulent charge
# shipping::delivered not received
# order status::not shipped::missing info
# damaged::outside warranty
# order::wismo::late
# pre-sale::product::back in stock::in stock soon
# product::review
# wholesale::cancellation::part of order
# pre-sale::discount::welcome discount::not received code
# mobile app support::mode control::off
# wholesale::pdf::damaged::evri
# donation request
# order status::shipped::wrong item received
# sales support::collaborations::partnership query
# checkout issues
# pre-sale::website issues
# questions::product::how to take
# recycling::other
# change order
# pro active::follow up::charge back
# points / promotion
# orders
# discount
# retail::return
# ordered by mistake
# shipping::tracking
# order related::order exchange::fit issue::womens
# collaboration::job
# delivered - not received
# amazon::return request
# incomplete order
# expiring
# digital product::account management::verifying teacher/parent identity
# feedback/review::positive
# fulfillment::defective item
# shipping::fedex/usps::delivered not recieved
# feedback::product::size
# wholesale::inquiry
# amazon::where is my order?
# order support::order status::items included in the order
# others
# faulty::in warranty
# shipping::wismo
# physical product::missing pieces
# yotpo::review::positive
# novelty/internal::misc
# wismo::post-shipped::received wrong item
# product information::product availability
# sales support::product info::plan details
# customer::negative feedback
# shipping - no tracking number
# shipping::when will my order ship?
# wholesale::order amend
# order::change::replacementorder
# returns- how to return
# kogan
# order::missing items::novelty mistake
# domestic returns/refunds/exchanges
# shopping - discount request
# account::questions
# order::damaged::shipping
# marketing/collab
# return::return refund status
# shipping::shipment status::usps
# shipping::lost shipment::canada post
# cx initiated::fraud
# not-support-related::service::feedback::negative
# klayvio
# faulty::faulty garment::leak complaints
# shipping::tracking number
# wismo::stocks exhausted
# payment method::harvest
# other::spam
# return/exchange::status inquiry
# shipping::delayed shipment::canada post
# hardware issues::temperature control
# site tech::complaints::incomplete sku
# existing order::refund
# wismo::post-shipped::delivered but missing
# pre-purchase::discount code issue
# shipping issue::policy ?s
# presale::policy inquiry::discount request
# pre-sale::account::other
# product::faulty
# pre-sale::corporate::invoicing request
# order support::delivery issue::damaged items received
# pre-sale::delivery::delivery times
# customer::advice
# product inquiry
# return::exchange::cancel
# shipping issue::damaged
# wholesale::pre-sales question
# order management::incorrect shipping address
# experiences
# rewards::tier status
# product feedback/quality::feedback/quality::materials::leather
# returns::returns policy provided::general returns policy inquiry
# partnership
# orders & deliveries::change of order::update style/colour
# order::missing/incomplete
# problema con un prodotto
# question::product
# pick-up
# order issue: refund
# tech supp::tech_query
# payment/refund question
# order::shipping inquiries
# general::loyalty / rewards
# orders & deliveries::incorrect item received
# production::roast quality
# order::where is my order?
# order::new::subscriber
# return::return to original payment method::return sizing
# technical difficulties::app
# authenticity question
# order issue::return::product issue
# feedback and complaints::product idea / request
# not-support-related::automatic reply
# rewards::combine account
# placing an order::taxes
# billing & payment::fraud notification::medium
# problem::return
# discount code
# contacting rem beauty::careers. 17b.
# support::product questions
# returns::returns policy provided::style not suitable::red
# stock adjustment::faulty
# product quality::expiring
# faulty
# product feedback/request
# gift order::additional packaging request
# partnership/ collaboration
# shipping::fulfillment mistake
# external channel::target
# product::how to
# feedback and complaints::positive feedback
# technical::account access
# post-purchase::return::refund inquiry
# pro active::follow up::voicemail
# subscription::change date
# general /admin::feedback - general
# tech supp::question
# pre-sale::recommendation
# product::product issue::damage/defect
# integration and automations::apple homekit::command failed
# feedback/request::request >> style/feature
# shipping::damaged in transit::ups::no vcare coverage
# other::dispute
# shipping::lost in transit
# shipping problem::package not delivered
# rem beauty 101
# other::marketing
# order::confirmation email
# customer::subscription change
# cancel request::price
# complaint
# partial refund
# order::invoice
# device setup::installation::question
# faulty::out of warranty
# pre-sale::identify part number
# idrive issue::item missing
# product::issue::expired
# post-purchase::return::return request
# existing order::price adjust
# annoyed by marketing emails
# contacting rem beauty
# device setup::pairing::ir pairing issue
# post-purchase::discount::retroactively apply::within week
# wholesale::pdf::plant & advise
# return: mto
# lost in transit
# customer::duplicate order
# sales support::product tech info::lawn size calculator
# returns::exchange request
# question::general
# pre-sale::promo code
# product::size
# integration and automations::apple homekit::disconnect
# cancellation::part of order
# wholesale::pdf::failed after planting
# post-purchase::other::sizing help
# wholesale::product information::aftersales
# physical product::hardware::broken seal
# wholesale::faire::new message
# competitor faq
# order issue::warehouse issue
# order related::order exchange::other
# biz dev::partnerships
# returns::delayed refund
# order::i found my order
# shipping::tracking request / update
# wholesale::order issue::boutique customer request
# product related::question
# sales support::product info::product longetivity
# reviews::general feedback
# collab request
# other::rocket money cancel
# returns::exchange
# return/exchange::loop request expired
# feedback/request::feedback >> product/style negative
# technical::charged with no order
# pre-sales::how do i place tax exempt orders?
# product return
# return::cancel::exchange
# return no reason
# product overview
# sf pro account - cancel account
# return/exchange::how to - general
# presale::product inquiry::size/style request
# purchasing::bolt upgrade program
# existing order::order question
# physical product::heat/shock (escalate)
# quality issue::pon
# order::pricing
# pre sale question::policy question
# return/exchange::returns policy::gift exchange
# technical::place order issue
# feedback::product::taste
# order inquiry::cancelation request
# post-purchase::shipping::marked delivered::dhl
# wholesale::auto reply
# billing & payment::purchasing::mysa::check out issue
# non service email::social media comment - no response required
# purchasing::tax refund request
# product information
# questions::product::whats best for me?
# reviews/nps
# existing order::shipping/tracking::duties/customs issue
# physical product::broken
# ticketing
# returns::returns policy provided::ordered wrong item
# buyback::buyback payment status
# shipping problem::address wrong
# stock adjustment::cont
# discount::inquiry
# brand/company::business/media inquiry
# pre-sale::conveyor / csi lead
# website::subscription ?s
# unsubscribe email & text
# recycling
# stock query
# product / costume
# faulty::faulty garment::inconsistent sizing
# problem::lost/stolen package
# order adjustment
# other::voicemail
# b2b::prospect
# web assistance::product availability
# other::gdc nomination
# loyalty
# pre-sale::product::back in stock::in stock
# damaged::by customer
# troubleshooting::error code::h2
# shopping- high risk order
# purchasing::invoicing/finance
# shipping notification
# no question asked yet
# invoice::purchase order
# job applicant
# tax exemption
# damage issue
# amazon::order issue::other
# duplicate
# fraudulent charge
# questions::product::will this work if i have ic
# payment::shopify charge
# troubleshooting::error code::h4
# return/exchange::returns portal confusion
# returns
# delivered with issues - item(s) missing from order
# feedback::neutral
# idrive issue
# quality control issue
# product query::product request
# purchasing::tax exempt
# order::update
# order::change::change-request
# returns::returns policy provided::style not suitable::modibodi
# faulty::faulty garment::faulty stitching
# bulk::order placed
# mobile app support::geofencing
# physical product::firmware::update
# international ordering::when will i received my order? 7f.
# physical product::hardware::motor
# product::inquiry::frontback
# broken pump
# mobile app support::energy saving and reporting::mysa energy usage::new issue
# questions::product::price
# wismo::post-shipped::missent/misshipped
# made-to-order::made-to-order status update
# orders & deliveries::missing/incomplete items sent::refunded
# b2b customer/inquiry
# fulfillment::received wrong order
# order::shipping::shippinginquiries
# order
# rewards::birthday
# order::amend::amend item(s)
# warranty::broken
# return and refund
# order::sku issue
# order::stolen
# n/a
# shipping::delay
# repair
# pro active::follow up::yotpo reviews
# amazon notification
# presale::policy inquiry::other
# product information::product dimensions
# other - leave note for mike
# wholesale::positive feedback
# payment terms::apply
# pricematching
# negative feedback
# order related::order return::fit issue::womens
# shipping::change address
# influencer::ugc
# chargeback
# misc::jml email
# order question
# system::website issue
# size/fit help
# general feedback::hall of flame
# product information::aftersales
# non service email::shipping notification
# pto
# order::edit::address::out-of-state
# order::i need to update/change my address
# shipping::delivered not received::reshipped
# rewards/referral/account::account >> general questions
# returns::returns policy provided::incorrect size too small::swimwear sports bikini bottom
# pre-sales
# other::urinary history
# retail::return::exchange
# order issue - missing or wrong item
# physical product::damage
# feedback - positive
# trust pilot::positive review
# feedback
# delivery/shipping::transit status inquiry
# order::missing item(s)
# tech support
# collaboration
# return::status inquiry::arrived at warehouse
# broken/defective device
# mobile app support::shortcuts::away
# influencer::ksc
# b2b::support
# order::status
# promo::apply promo
# shipping issues
# returns & exchanges::exchange
# physical product::known issue-open::codebit fw issue
# wismo::post-shipped::order returned - rts
# refund status
# orders & deliveries::change of order::change of address/customer details
# damaged::other
# post-purchase::other::chargeback
# orders & deliveries::return to sender
# novelty/internal::xln issue
# shipping problem::delivery exception
# nothing naughty
# order::shipping issue
# order support::cancel::duplicate order
# mobile app support::mode control::cool
# wholesale::wismo::in pick
# junk mail
# shipping information::shipping cost
# shopping- payment card issues
# amazon::other
# question::restocking
# shipping information::import duty and customs
# general::marketing/partnership
# cancellation::full order
# orders::out of stock
# contacting rem beauty::how can i contact management? 17a.
# quality issue::promote
# tracking::delayed parcel
# fulfillment::vip::beyond window
# wholesale::wrong item::flowered incorrectly
# digital product::classroom management::classroom management
# shipping issue::delay
# return/exchange::general questions/other
# return&exchange::not eligible::outside return window
# ask for shipping refund
# pre-sale::pricing questions
# product query::other::internal features
# existing order::order error::system error
# change/cancel order::change >> size
# existing order::order error::agent error
# it ticket
# wholesale::delay order
# presale::product inquiry::style recommendation
# other::event planning
# product::feedback::positive
# wholesale::order confirmation/vat receipt
# buyback::buyback process
# delivered but never received
# post-purchase::shipping::late delivery::usps
# cancel request::i don't want a subscription
# general::panky points
# pre-sale::website questions
# return/exchange::product issue::not as advertised
# wismo::lost in transit
# product::testers
# pre-purchase::question
# shipping::canada shipping::delay::canada post
# other::marketing/press
# account management::unable to login
# why was my order cancelled?
# product::feedback::negative
# feedback::portal/website
# discounts and credits::promotion extension
# wholesale question
# warranty
# payment::refund
# customer::friendly feedback
# order::cancel::not shipped
# order management::cancel order
# shipping issue::royal mail
# sizing::help::sleep bags
# orders::shipping::shipping inquiry
# shipping - parcel lost/stuck in transit
# return/exchange::label not received
# shipping issue
# price matching
# order change::order cancellation
# questions::product::how it works
# shipping::delayed shipment::usps
# internal
# spam::email
# discounts and credits::discount request
# pre-sale::delivery::courier query
# return/exchange
# rewards/referral/account
# shipping::delivered-not received/stolen::ups::vcare coverage
# device setup::pairing::pairing issue
# enquiry::other
# order support::return/replacement::replacement request
# cancel & refund::not fulfilled::changed mind
# fulfillment::order status
# website ux/technical issue::checkout
# assembly help
# product::question::fit
# problem::damage/defective
# advice
# purchasing::cc link
# damaged order
# other::wholesale
# amazon
# where is my order?
# button replacement
# subscription::cancel subscription
# post-purchase::shipping::xb::other
# pre-sale::maintenance manual
# feedback/review::negative
# order status
# wholesale account request
# cancel requests, order changes, rts
# fraud
# order::refund::fit
# general sales::international
# order::wrong order
# order::change::cancelsubscription
# general sales::style help
# service::feedback::positive
# order support::edit order::upgrade plan
# customer::track order
# post-purchase::shipping::late delivery::fedex
# post-purchase::shipping::marked delivered::usps
# wismo::post-shipped::tracking hasn't updated
# shipping::fedex/usps/canada post::delivered not received
# other::doctor samples
# other::social
# purchasing::quote request
# not-support-related
# rewards/referral/account::account >> general questions/other
# domestic shipping
# other::collaboration
# charged twice
# refund::mbg
# product issues::already open
# product information::general
# hardware issues::installation::shorted unit
# address change
# recycling::customer
# biz dev::influencer
# damage/defect::manufacturing defect
# account management::creation::error creating account
# policy question
# shipping issue: delivered, not received
# product::quality issue
# pre-sale::corporate::snack box enquiry
# digital product::known issue-closed::macos 13.3 canvas
# shipping::claim::route
# return::outside return window
# feedback/request::request >> size request
# questions::international shipping
# change/cancel order::change >> address
# post-purchase::change order::change item
# review::trust pilot::positive review
# product::pre-sale
# wholesale::wismo::on the way
# pre-sale::discount
# external channel::other
# forwarding::wholesale
# samples
# order support::delivery issue::order returned to sender
# returns::return status
# rewards::larger redemption option
# virtual fittings
# order support::delivery issue::order lost in transit
# wholesale::faire order
# discount inquiry
# wismo::post-shipped::missing item from order
# unsubscribe/data removal::do not mail (physical)
# discount inquiry::military/nurse/etc
# feedback::commercial
# post-purchase::change order::discount code
# forwarding::marketing
# order support::delivery issue::order marked as delivered
# order::product-processing::bottle fill line
# wholesale::general question
# shipping issues::usps
# stock::stock levels
# shipping issue::damaged product
# fulfilment::incorrect item
# shipping issue::order did not ship (label created; no movement)
# support::product questions/issues
# wrong item received
# qa::foreign object
# general /admin::social
# return::incorrect item
# wholesale inquiry
# order support::edit order::incorrect address provided
# product feedback/quality::faulty/damaged::materials::leather
# cancel and refund
# web assistance::issue at check-out
# digital product::instructions unclear
# question::aftersales
# sales support::stock availability::stock availability
# shipping::not received::usps
# shipping issue::delayed order
# job enquiry
# shipping::delivered-not received/stolen::ups::no vcare coverage
# orders::order status
# shipping::delivered not received::found
# questions::retail
# product information::chain and pendant compatibility
# website::glitch
# missing item
# post-purchase::shipping::late delivery::ups
# wholesale::wismo::delivered
# shipping information::international shipping
# return request
# account management::creation::unable to verify account
# problem::other
# delivery/shipping::packaging feedback
# questions::requesting a phonecall
# purchase order
# shipping::lost shipment::usps
# orders & deliveries::missing/incomplete items sent
# order support::edit order::reschedule shipment
# return::refund question
# not-support-related::spam/solicitation
# existing order::shipping/tracking::damage on arrival
# brand/company::business inquiry
# shipping::delayed order
# okendo::reviews::1-3 star::4-5 star
# retail: resolved by phone/what's app
# forwarding::it
# biz dev::press
# shipping issue: delay
# pre-sale::style locator
# order::address issue
# wismo::pre-shipped::gift box
# side effects
# pre-sale::question::size
# rwp::plap
# wholesale::update customer information
# product problem::product lost
# fulfillment::missing item
# return::promotion::price match
# looking for a sample
# vip
# amscan::general
# shipping::dpd returned parcel
# promotions::discount request
# spam/non-support-related::spam/testing
# questions::breastfeeding/pregnancy
# pre-sale::shipping quote
# refund::mbg::pon
# order support::cancel::overpriced product
# subscription::process today
# feefo::positive review
# shipping problem::tracking wrong
# non-customer::vendor::too large for parcel
# no response needed (triage)
# collaboration::influencer
# wanting to change their email address
# marketing influencer request
# subscription::change payment information
# other
# shipping problem::return to sender
# shipping::lost in transit::ups::vcare coverage
# shipping request::hold for pickup
# delay order
# post-purchase::return::exchange request
# product advice
# order management::shipping question
# return/exchange::returns status::chasing
# rewards/referral/account::rewards >> general questions
# shipping::other
# store message::training
# feedback::other
# usage updates::neutral/don't know
# stock inquiry
# return::dhl return
# general inquiry
# retail::other
# return::gift return
# cancel request: doc orders
# post-purchase::other::other
# digital product::warranty
# payment::shopify chargeback
# domestic returns/refunds/exchanges::my item arrived damaged. what should i do? 5a.
# external channel::target::review
# pre-sales::when will these be back in stock?
# digital product::classroom management::sphero edu classroom
# distribution::shortage
# advertisement::services
# pre-purchase::compatibility question
# returned to sender
# misc::spam
# return
# promo is not working
# wismo::on the way
# orders::payment::invoices&tax
# warranty::question
# return&exchange::gift returns
# order status::shipped::delays::dhl
# warranty & damage::damaged in shipping::ltl
# fulfillment::out of stock::policy::free shipping request
# product::availability
# pre-sale::sales_query
# subscription::add otp
# non-customer::csi
# account management::shared user::unable to add / confirm account
# customer account
# education::technical question
# system::payment issue
# return/exchange::refund/status inquiry
# exchange/return::change of mind
# support::gardening questions
# damaged::gift
# order::cancel/change/address
# payment method::paypal
# wismo::returned by courier
# general /admin::donation request
# digital product::product accessibility
# digital product::account management::account deletion request
# order query
# return::return request
# amazon::question
# forwarding::pd
# not applicable
# feefo
# payment::issues
# job enquiry::retail
# account::account issues
# store message::qas
# feedback::negative
# order inquiry::line item cancelation request
# return::faulty
# domestic ordering
# fulfillment::cancel
# return/exchange::request expired
# purchasing::rfp
# shipping issue::delivered not received
# order support::delivery issue::incorrect items received
# forwarding::office
# size/fit help::no items yet (new customer)
# mobile app support::mode control::swing
# technical difficulties::website
# pre-sales::product questions
# post-purchase::return::other
# pre-sale::account::login issue
# faulty::faulty garment::hole in the gusset - alkaline
# return::exchange::authorization hold
# delivery - rts
# general::other
# customer::address change
# spam::social media
# pdf::damaged::packer damage
# product inquiry::product availability::out of stock items
# orders & deliveries::order error in cin7/kiosk/3plukcore
# fulfillment::edit address
# product inquiry::product care
# trust pilot::negative review
# orders::changes & cancellations
# order status::po not received
# order support::edit order::change plan
# pre-sales::do you accept purchase orders?
# influencer
# rwp::faulty
# order related::order return::damaged product::mens
# question::sizing
# fulfillment
# shopping support::payment support
# existing order::cancel order
# shipping problem::shipping delay

# %%
import numpy as np

data_dict = {
    'key1': [1, 2, 3, 4, 5],
}

values_array = np.array(list(data_dict.values()))

mean_value = np.mean(values_array, axis=0)

print(mean_value)
# Out:
# [1. 2. 3. 4. 5.]

# %%
values_array.shape
# Out:
# (1, 5)

# %%
ticket_message_list = TicketMessage.from_dataframe(dataframe=df)

# %%
i = 13524

print(f"Account id = {ticket_message_list[i].account_id}")
print(f"Ticket id = {ticket_message_list[i].ticket_id}")
print(f"Contact Reason = ", ticket_message_list[i].contact_reason)
if ticket_message_list[i].email_sentence_embeddings:
    print(f"Number of sentences in email = ", len(ticket_message_list[i].email_sentence_embeddings))
else:
    print(f"Number of sentences in email = ", 0)
# Out:
# Account id = 4453
# Ticket id = 375526423
# Contact Reason =  "Post-purchase::Other::Other"
# Number of sentences in email =  3
